# %% [markdown]
# ### In this project we aim to clean the text and implement both count vectorizer and TF-IDF vectorizer for creating the DTM - Document term matrix which will be used to train the base models. Build Multinomial Naive Bayes Model, Decision Tree Classifier and Logistic Regression Model and compare the results

# %%
import pandas as pd
import numpy as np

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.tokenize import RegexpTokenizer
from nltk.stem import LancasterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

import string
from six import string_types
from bs4 import BeautifulSoup


from textblob import TextBlob
import matplotlib.pyplot as plt
import requests

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

lancaster=LancasterStemmer()
lmtzr = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jervissaldanha/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jervissaldanha/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jervissaldanha/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## Import the data into a dataframe

# %%
data = pd.read_csv('sarcasm_detection.csv')
data.head()
# Out:
#            ID                                            comment     date  \
# 0  uid_590555  Well, let's be honest here, they don't actuall...  2015-04
# 1  uid_671762  Well, I didn't need evidence to believe in com...  2016-12
# 2  uid_519689              Who does an "official promo" in 360p?  2013-11
# 3  uid_788362                           Grotto koth was the best  2015-09
# 4  uid_299252                                   Neal's back baby  2015-11
#
#    down                                     parent_comment  score  top  \
# 0     0  They should shut the fuck up and let the commu...      2    2
# 1    -1  You need evidence to kill people? I thought we...      6   -1
# 2     0                    2014 BMW S1000R: Official Promo      3    3
# 3     0  Not really that memorable lol if you want memo...      2    2
# 4     0                      James Neal hit on Zach Parise     -5   -5
#
#               topic            user  label
# 0       starcitizen  Combat_Wombatz      0
# 1  EnoughCommieSpam        starkadd      1
# 2       motorcycles         phybere      0
# 3        hcfactions          m0xyMC      1
# 4            hockey       Somuch101      1

# %%
comments = data.comment.copy()

# %%
comments.head()
# Out:
# 0    Well, let's be honest here, they don't actuall...
# 1    Well, I didn't need evidence to believe in com...
# 2                Who does an "official promo" in 360p?
# 3                             Grotto koth was the best
# 4                                     Neal's back baby
# Name: comment, dtype: object

# %% [markdown]
# ## Clean and preprocess the text data:

# %%
# - Tokenize
# - Case conversion to Lower Case
# - Removing Punctuation & Stopwords
# - Stemming & Lemitization

from nltk.stem import LancasterStemmer
lancaster=LancasterStemmer()

import nltk
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('wordnet')
lmtzr = WordNetLemmatizer()

def process_tokens(tokens: list) -> list:
    processed_tokens=[]
    for token in tokens:
        punct_and_stop_words = set(stopwords.words('english') + list(string.punctuation))
        processed_tokens = [lmtzr.lemmatize(token.lower()) for token in tokens if token.lower() not in punct_and_stop_words]
    return processed_tokens
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jervissaldanha/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from cleantext.sklearn import CleanTransformer

cleaner = CleanTransformer(no_punct=True)
cleaned_comments = cleaner.transform(comments)

# %%
comments
# Out:
# 0        Well, let's be honest here, they don't actuall...
# 1        Well, I didn't need evidence to believe in com...
# 2                    Who does an "official promo" in 360p?
# 3                                 Grotto koth was the best
# 4                                         Neal's back baby
#                                ...
# 14995    Well with a name like El Cubano I'm surprised ...
# 14996                            ... This is a good point.
# 14997                                                 Yep.
# 14998     That's what the government WANTS you to believe!
# 14999    because Windows 10 has the glorious start menu...
# Name: comment, Length: 15000, dtype: object

# %%
cleaned_comments
# Out:
# 0        well lets be honest here they dont actually se...
# 1        well i didnt need evidence to believe in commu...
# 2                       who does an official promo in 360p
# 3                                 grotto koth was the best
# 4                                          neals back baby
#                                ...
# 14995    well with a name like el cubano im surprised h...
# 14996                                 this is a good point
# 14997                                                  yep
# 14998       thats what the government wants you to believe
# 14999    because windows 10 has the glorious start menu...
# Name: comment, Length: 15000, dtype: object

# %%
### Clean & Tokenize
data_list = list()
for text in cleaned_comments:
    data_list.append(RegexpTokenizer('\w+').tokenize(text))

## print Example
print(data_list[:3])
# Out:
# [['well', 'lets', 'be', 'honest', 'here', 'they', 'dont', 'actually', 'seem', 'to', 'do', 'much', 'moderating', 'so', 'they', 'have', 'to', 'spend', 'their', 'time', 'doing', 'something'], ['well', 'i', 'didnt', 'need', 'evidence', 'to', 'believe', 'in', 'communism'], ['who', 'does', 'an', 'official', 'promo', 'in', '360p']]

# %%
cleaned_corpus = list(map(process_tokens, data_list))

# %%
cleaned_corpus = list(map(lambda lis: " ".join(lis),(cleaned_corpus)))

# %%
cleaned_corpus
# Out:
# ['well let honest dont actually seem much moderating spend time something',
#  'well didnt need evidence believe communism',
#  'official promo 360p',
#  'grotto koth best',
#  'neals back baby',
#  'orange new black house card hemlock grove going see sense8 worth watching hype',
#  'pff everybody know science sexist',
#  'called rmmas golden boy sage shitlist since',
#  'he dude though',
#  'probably shouldve followed original comment',
#  'thats gonna look great later life',
#  'nonsense bookstore competitive price way leverage location',
#  'least asus known putting quality ram android device',
#  'dont equate stance rice',
#  'since federal law start applying military',
#  'take fistful shrooms go watch holy mountain way meant enjoyed',
#  'id date id date hard',
#  'thought sub balance fun walking spawn kill sentry gun placed',
#  'oh yeah well doctorate c master soldering iron',
#  'wow glanced history racist antisemitic comment impressive sir impressive',
#  'took guy long',
#  'could put suck john oliver dick',
#  'got fam',
#  'get worse one top pro player queue long smite actually crashed',
#  'he sexy man',
#  'yeah reddit isnt billion dollar business half billion single purpose',
#  'wow credit bargnani',
#  'tee time doctoh xd',
#  'absolutely',
#  'lol well trademark issue yeah imagine bbc isnt going sue soviet carwashsky',
#  'seems like pretty nice guy tbh',
#  'say arent racist',
#  'right letter condemnation',
#  'sentiment ive gotten friend people thread park incomprehensible random spirally order dont even try game get want get',
#  'like capulets romulins',
#  'gospel human slave',
#  'high 120 pretty good though',
#  'much cost',
#  'must real nice person',
#  'right smack midst dnc convention would glorious',
#  'heavenly father disappointed',
#  'shut paddy',
#  'example',
#  'wont stop somehow prove wind farm sole source global warming',
#  'go extra mile get black led man',
#  'right',
#  'handed he black',
#  'maybe someone else translate',
#  'dude robot ask',
#  'cousin would probably get frustrated real fast',
#  'funny find 30 minute video interested watching cant sit 10 minute wanting go grab something eat eat watch',
#  'clearly upset personal agenda',
#  'yeah man everone midwest worthless biblethumping hillbilly',
#  'dont worry im sure reporting probation week keep line',
#  'think meant knicks',
#  'clearly easy draft franchise qb thats every team one',
#  'let kill guy rip em limb limb',
#  'thats he saying need license attempt prevent owner raise dog poorly able',
#  'help defrag securely wipe free space often possible best performance longevity',
#  'first video ive seen man sky came close cry beautiful',
#  'mythical 05 damage keep hearing',
#  'wow spooky really got man',
#  'hopefully t34100 thing underpowered like using tier 1 tier 4 match really need buff',
#  'come close meaning',
#  'infinitely comfortable old hifiman headband',
#  'bud norris get room wait would gay',
#  'girlfriend hate loud current taco freeway time new girlfriend',
#  'like way dribble',
#  '',
#  'couldnt possibly ea buying positive review',
#  'couple nerd',
#  'idea idiot talking',
#  'yeah like he progressed juve',
#  'thats said',
#  '',
#  'maybe take better care shit',
#  'youd think diversity would good editorial company',
#  'bill great bos',
#  'get ptsd',
#  'theyre white cant racist',
#  'holy crap actually baby ultrasound told u day going 85 pound came 10 lb 4 oz',
#  'point cant cannabis cure',
#  'yeah game united poor',
#  'bah another onrails shooter',
#  'dibs rib',
#  'handle way handled beta launch bf4',
#  '31 year creepy',
#  'max cape damn pleb',
#  'greeaat lifelong dream',
#  'well there one thing know jew let kid rape kid meth',
#  'annexed sooner later',
#  'wanna see one dipped custard',
#  'quick start rumor domain registered bombing',
#  'nah man inertia trailer keep tipping long turn sharp enough',
#  'really learn control claustrophobia comfort',
#  'humidity probably',
#  'wasnt reading voice hit uh uh',
#  'yeah thats rather backpack im going distance tbh dont like driving lol',
#  'probably alt tabbed defusing',
#  'hope get hawaiian shaved ice vanillite family',
#  'thats supporter stop frisk want',
#  'oh boy 4k kinect sport rival',
#  'one tell thackeray term akhand bharat',
#  'he carrying explosive since jet fuel cant melt steel beam',
#  'fun fact video filmed week east coast u',
#  'tumblr tm go',
#  'isnt normal id head dentist bruh',
#  'gaming taught always take wrong path first dont miss loot',
#  'probably fucking refill either',
#  'yeah 14 little young facebook',
#  'mcnypd',
#  'immersion breaking',
#  'run gas',
#  'exactly',
#  'unscoping restores widowmaker 100 movement speed brief period allowing seamless repositionining',
#  'hahaha okay lost one good night get well soon',
#  'ah yes people hand half money state goodness heart force',
#  'well unique',
#  'well like op worry knocking',
#  'wow original idea dont know noone trying',
#  'isnt called salmonella',
#  'thing movie isnt great',
#  'watch',
#  'turbin',
#  'like ahfh civil war',
#  'oh thought said huh gif wasnt working something direction',
#  'lol missed',
#  'bbut bcnd said get paid vacation time commendation',
#  'replace pair',
#  'like skill queue',
#  'lovingly crafted lovecraftian game',
#  'well doesnt make sound like troll',
#  'nope gun must pointed chest finger must pulling back trigger 50 reasonably believe intend harm',
#  'sound reasonable gtfo',
#  'thats new york football giant',
#  'got shocker house card asshole bring back',
#  'man eyepatch suitcase sam guy gave onion hamburger onion trade',
#  'shard greed',
#  'tactical',
#  'really think lebron gonna make phone call adam silver',
#  'firework nats game',
#  'thx',
#  'definitely complement',
#  'glad pyro win get nerfed heavy',
#  'instead making memorize periodic table extended investigation us particular element',
#  'eh miami traffic probably little better dc traffic',
#  'yeah console version better',
#  'must heard enough extra screen display additional row apps',
#  'else get green light buy everything au',
#  'fear fantastic motivator',
#  'champaign county jail basketball team going stacked',
#  'clearly cant anything right',
#  '4v4',
#  'yeah shes downright ugly pile trash filthy garbage vomit',
#  'wow relatable charming maybe ill vote',
#  'direct result patriarchy thus fault men',
#  'thread end well',
#  'care anything besides money manager really perfect psychopath employment think',
#  'thanks speaking sooner',
#  'tell often ask men dinner',
#  '5 6',
#  'emulated since computer dont run do anymore',
#  'hunter even need ammo go invisible run away like puny coward',
#  'first realized consistently last thing thought going bed first thing thought waking',
#  'guess market sort',
#  'he busy',
#  'man obama strong leader willing put boot ground starting border march thing costing hundred thousand life obamas weak president nothing except take head enemy organization two month establishment',
#  'know im late party pls dont use allbrite',
#  'nice try feinstein',
#  'family racist',
#  'yeh great got torture people u',
#  'like new mexico',
#  'upvoted comment person commented bad redditor',
#  'dark humor still humor',
#  'fucking god agreed cringe peppy please ban',
#  'refuse rez people general',
#  'comforting',
#  'dont live ontario',
#  'looking like prime time devin hester',
#  'downvote downvote question',
#  'bet there lot interest question',
#  'seems super effective getting gw raid fixed',
#  'power friendshipintensifies like link intensifies instead link address',
#  'tournament start new year eve new year day',
#  'there 2 whole spice bread',
#  'hard take seriously write shitty xenophobic comment',
#  'true adam sober month gotten major trouble totally think ready take parenting aub',
#  'creates downforce car hauler',
#  'korean several time id',
#  'nearly fell chair laughing flag right front face',
#  'add matrix represent transformation basis 1i',
#  'well corporation people friend',
#  'go gamestop play console',
#  'wont frustrate',
#  'one recommended people commit potential felony order discourage burglar',
#  'yeah land size population density nothing',
#  'title make angry',
#  'life changing amount money',
#  'well watermark said made amigo loan shady coborrower paydayesque loan company high interest rate yeah im sure theyre helping achieve goal responsibly',
#  'seems trend white',
#  'best choice chief lovely allas leo2av better regard',
#  'found 8yearold cod kid',
#  'think real joke playing samus',
#  'pm link',
#  'wildly disappointed incredibly relieved never knew allowed thing school picture',
#  'brian wilson beard stat would like 200',
#  'buy 1000 tv 600 sell 800 sale done youve made 200',
#  'job pay dz cash',
#  '14 year',
#  'predict backpedaling scout occupied even easier getting heavy pick',
#  'many thousand probably million incredibly ignorant redditors despite widely available evidence end vote criminal scum anti america traitor committed actual treason shillary therefore need widely frequently spread reddit much corrupt criminal dirtbag anti america treasonous neocon globalist',
#  'yeah gang never kill innocent people',
#  'pronouncing ahvee something',
#  'camera doesnt fit apartment',
#  'comment make happy',
#  'yeah people 100 satisfied get accept happy even crap',
#  'good luck finding committed relationship',
#  'let face',
#  'protecting speech agree totally point',
#  'survival',
#  'yea get spider broodmomma',
#  'even accepting true',
#  'theyre afk literally pose zero risk',
#  'im sure plenty genuine racist identifying crime problem ethnic subgroup racism despite try tell u',
#  'welcome',
#  'people hate free crit mini sentry youre crazy man',
#  'zardoz',
#  'maybe maybe p',
#  'err520',
#  'realised',
#  'bad didnt realize seemingly benign ribbon trophy would completely destroy personality inside leaving spoiled entitled mess',
#  'aww wish could say thank tho',
#  'mean abandoning viable twostate solution consequence',
#  'id say counselling himher',
#  'bit 2edgy4me',
#  'depends scandezzy take slapper lol',
#  'doubly theyre gay couple',
#  'mom send picture mail greatest one liner ad ever',
#  'yeah league known aweful game devs ability whatsoever',
#  'ya didnt woman wasnt reason get arm despite one worse',
#  'look great interesting funyah horrible',
#  'even misplayed brief amount time',
#  'im mailman ive delivering deaththreats guy stop',
#  'wise',
#  'galatavi put makeup every morning',
#  'could ignite caster minion free 5adap',
#  'mia sollis',
#  'stayhealthy',
#  'wish',
#  'tagged adolf shitler',
#  'thats got keynes quote',
#  'like age 3065',
#  'also remember breathe try walk front moving bus',
#  'know guy dating someone much physically attractive immediately come genuinely nice fun person',
#  'uk fail lost leverage eu eu going make example quell country trying follow suit',
#  'could still youd obscenely rich poor money',
#  'would frame picture kobe dunking soft coward',
#  'america certainly doesnt pull hissy fit china build shield',
#  'im nightmare zone prod',
#  '03 watt comparison',
#  'welcome',
#  '1 psychology',
#  'cliche',
#  'swag manbag',
#  'prop creativity',
#  'trump piece shit',
#  'yeah always forget many ultra lib cuck college kid chat',
#  'kill nonwhites course',
#  'well debil already corrupted people would bother',
#  'oh well case hilarious lost cringeworthy status',
#  'thank judicious saving medical welfare program',
#  'thought gumi patched c1 elixir steal last update',
#  'look like got shadowbanned click profile say 404 found',
#  'never seen error',
#  'really surprise',
#  'he also womaniser chronic bigot let slide he funny telly',
#  'look like fancy pc mouse',
#  'got morata mate set treble',
#  'fuck son',
#  'without giving result bit wrong he one western player get world semi',
#  'staking claim watch show think unfold',
#  'yeah shouldve rescheduled',
#  'use esc send dispatch log start end time billing inventory',
#  'prove',
#  'im happy pal still explicitly stated opinion piece unlike initially characterized',
#  'people say igthft declining think posting cute vids really nail',
#  'he scrappy',
#  'cant spadina nowhere near enough people bus',
#  'coming guard shin',
#  'expect group spy',
#  'obviously said',
#  'oh well im sure femfreq offer slot need',
#  'bill continue move',
#  'would logical definitely ubisoft evil massive care monies',
#  'autocast build probe',
#  'something something every thread',
#  'dont think personnel beat game tonight',
#  'yeah',
#  'babylon 5 blu raysigh id sell soul b5 blu',
#  'least challenge mode',
#  'unless beginner',
#  'lllllliar',
#  'like',
#  'killer mikekiller mikekiller mikekiller mikekiller mikekiller mikekiller mikekiller mikekiller mikekiller mikekiller mikekiller mikekiller mikekiller mikekiller mikekiller mikekiller mikekiller mike',
#  'move different town want marriage license',
#  'eye cant see past 1 fps anyway',
#  'dont smile',
#  'dhoom responsible death',
#  'stern knowing eye',
#  'please tell female hairy leg male wearing tom',
#  'racist white poll mystical power shit',
#  'threat trump make shouldnt viewed stand ground case',
#  'religion peace',
#  'youre right didnt think',
#  'blacklivesmatter racist cop',
#  'isnt footage winter olympics',
#  'succeeded',
#  'well let say english welsh',
#  'he real black swordsman',
#  'everyone want matchmaking raid obviously everyone know sword',
#  'fucking casuals skipping cod get married',
#  'oh bad',
#  'someone seems hate police enough openly insult instead acting like decent human obviously make valid unbiased point police',
#  'ayuh',
#  'never seen hacker kinda hope see person',
#  'nah problem',
#  'try buy clan whenever possible',
#  'boy really lucky',
#  'time two game tomorrow',
#  'play old one play new one',
#  'khaki usa equivalent chino',
#  'spelled way sound like say even spelling awful',
#  'balkanite perk racial 95 immigrant repulsion',
#  'since third grader wouldnt randomly attack someone first place think scenario assumes reason drive keep fighting',
#  'eqrw would pretty disgusting ahead',
#  'third',
#  'buuut earth flat',
#  'wow didnt know baker',
#  'nah cant',
#  'half man half god full sunburn',
#  'right handed left arm stronger',
#  'squat shoe',
#  'yeah im sure thats country he heard',
#  'dont understand klay go forward photo like ask retake',
#  'yes rope still normal',
#  'bitch friendzoning nice guy tm waited outside',
#  'even need ar15',
#  'yeah way actually belief indy darling aint allowed positive opinion roman',
#  'mensrights',
#  'indication danger female protagonist video game',
#  'twin game thread 490 one 158',
#  'umm ever studied developmental economics',
#  'built whole thing using single allen wrench',
#  'im cutting skin dick cool',
#  'tell updawg really want know care please tell',
#  'like rocky iv montage',
#  'cool really force plot point order give excuse boob window',
#  'forgot',
#  'need chicken',
#  'really know going used anyway people plane effectively already dead',
#  'thats bad',
#  'dont see cop using waze make le effective avoiding cop',
#  'provide someone healthcare educate police neighborhood put fire apparently',
#  'probably russian put money',
#  'likely alien christ',
#  'papa rickon rocking week ago even sansa hair pulled back similar manner',
#  'dont donald trump leader gave stevan harper boot maple syrup great soldier peace keeper wariors fight great job cough ww1 also else leaf flag eh',
#  'huehuehuehuehue',
#  'im sure celestial glyph ele make feel super powerful destructive',
#  'sanogo',
#  'clinton foundation funneled money group carried benghazi attack',
#  'like biggest member founder tape comparing blm isi sympathizing isisyea racist hate group disguised good cause',
#  'yeah well least tampa bay didnt give 500 passing yard steelers',
#  'kneepads',
#  'unless anywhere earth seems',
#  'get logic reasoning racist',
#  'touched care enough put misery',
#  'sure definitely dont pay taxed province canada',
#  'hopefully one day scientist solve confusing problem',
#  'hope team bus crash everyone get season ending careerthreatening injury',
#  'little walk fresh might nice',
#  'think explanation translated newspeak fuck constitution im juggernaught bitch',
#  'wasnt gandhi kind dick way',
#  'fight clubnever seen',
#  'yeah used sbc buffon',
#  'yes kitten grown cat',
#  'say espns article incorporation',
#  'best idea ever',
#  'nvm',
#  'easier imagine future look good',
#  'much better freeway',
#  'handing essay mad legend hedidthat',
#  'pleb comment beneath u',
#  'die free pain live fight sorrow ffx',
#  'yeah thats',
#  'ive playing game since like 8 im 23 lol hard',
#  'yes go east problem racism place like china japan',
#  'downvotes god way saying youre going hell',
#  'two girl unlocked get girl get venus',
#  'youre gonna bad tom',
#  'well know one thing sure certainly wouldnt ordering',
#  'get smeared face',
#  'found homeland',
#  'he buying he smart',
#  'youre right manthe guy replaced perfect u',
#  'somebody go tell',
#  'course dm override rule storytelling purpose rarely used',
#  '4 exclusive said thing good sign since common',
#  'next time try hit guy red',
#  'example game smite online moba like league legend hired caster named goldenboy past 2 world championship stream awkward listen analysis doesnt play game doesnt really know mechanic depth',
#  'damn never knew sniper could use minigun',
#  'life isnt worth living without least 1 2 slave',
#  'k',
#  'maybe hold alt accidentally selling restock',
#  'enough apm',
#  'nice one',
#  'masterpiece snake revenge',
#  'mhmm nice',
#  'mgelol',
#  'fucking crutch',
#  'there decent number uncommon rare item look like shit sell peanut useful crafting',
#  'saint row series different gta good way imo',
#  'thanksfor reminding',
#  'think he bitter last season',
#  'excessive use force',
#  'im offended comment',
#  'aw come everyone love skip bayless',
#  'trying say bulk islam dangerous people practice passively exception',
#  'hell clearly labelled racist saying black guy like people racist saying white guy',
#  'free book',
#  'next month',
#  'troof',
#  'youre assuming doesnt boob match could hourglass shaped man',
#  'overunder many game last',
#  'youre looking right one',
#  'well exactly kind guy want represent church lifelong member',
#  'butbutsalaries',
#  'time',
#  'well never happened lol sure hope doesnt become regular thing',
#  'sound like gun id definetly solution',
#  'idea sorry',
#  'sure he blowing shit im unfollowdont care much love music thats inexcusable',
#  'thank',
#  'must great comfort people dealing major depression schizophrenia bipolar disorder know mental illness dont real',
#  'mess narrative',
#  'oh huh thats nice',
#  'people using circa q4 2016',
#  'well seems reasonable',
#  'oops lol edit quote',
#  'hd598 two hd600 must pretty similar',
#  'im worried karma mean everything',
#  'communist',
#  'ok read one guy girl asked date didnt realize liked son might retarded',
#  'show bing google',
#  'mean someone would cheat personal gain',
#  'racial commentary',
#  'would keep buying pledge needed',
#  'get fined dont register though',
#  'people still alive',
#  'youll surely make game replace tl',
#  'shhhh dont tell',
#  'problem iphone 6 far',
#  'yea theyre giving everyone security safety',
#  'doesnt save every 30 minute must noob',
#  'choker',
#  'rest rpics high quality',
#  'easily best trilogy',
#  'true doesnt change fact kid spoiled least material sense sense entitlement',
#  'yeah woody allen isnt funny',
#  'hey baby',
#  'throw super glue itll fine',
#  'brilliant idea really',
#  'mercedes incident',
#  'cartridge',
#  'deck play',
#  'upvoted educational purpose',
#  'ok requires sex donald trump',
#  'destiny take cake',
#  'total miss local coverage doesnt pull',
#  'rocky butte',
#  'realise ht electric tower go reserved forest',
#  'daylight come wanna go home',
#  'make sense kobe fan',
#  'thats always best source interesting build',
#  'feel microaggression internet',
#  'cosplay consent',
#  'banshee',
#  'barry bond',
#  'everyone would realize theyve wrong whole problem go away',
#  'almost like satirizing incestuous element show like game throne',
#  'three word triangle life',
#  'oh right cause everyone know social issue dont matter right',
#  'yeah real service tangible good acquired skill fluff like pyramid campaign riding coat tail get',
#  'point doesnt really change anything would serve nothing beyond moniker point',
#  'oh thanks hadnt worldnews yet today',
#  'gotten 15',
#  'sent message disapproval destroying also gave george zimmerman money buy gun',
#  'bet late afternoon early evening hed also lurking hiding',
#  'ugh youre open minded',
#  'didnt know fine stereotype white people',
#  'cant wait kuro roamed top try kill koro koro successfully avoided gank koro recalling kuro go back mid',
#  'yeah also really enjoy completely changed character zack snyders murderverse',
#  'bread',
#  'government regulated utility exact thing recourse',
#  'well certainly wouldnt expected unnecessary top gore eli roth',
#  'put led wheel match led',
#  'da racish',
#  'paladin doesnt get one cuz pally',
#  'there one thing could help indie dev community samsung phone variant',
#  'life much better since installed sjw skeleton thingy always make chuckle',
#  'precisely',
#  'demonstration sincerity',
#  'bet early copy man sky',
#  'source taking anus',
#  'fake man sky isnt even yet',
#  'hippopotamus',
#  'ah gubberment idea ya cant upvotes saying',
#  'yay democracy',
#  'travel snowboarding found favorite place lived',
#  'support',
#  'thought cold pizza breakfast food',
#  'minecraft taught theyre interchangable',
#  'know theyre adjustable right',
#  'illuminati got',
#  'look see decoration spreading',
#  'thats harassment pig',
#  'yes downloading dedotated wam make every game run smoothly',
#  'sale background check already',
#  'id extremely hard time deciding ferrari 458 italia',
#  'except cant really tell people step outside want fat',
#  'guy tell much worked',
#  'redundant state redundancy',
#  'still final bos amirite',
#  'dude wheres car',
#  'shot fired',
#  'ben ghazi feller still trained hillary get ready another terrorist attack know',
#  'hulk win 1010',
#  'yea architect',
#  'quran',
#  '35s',
#  'hater',
#  'fucking pas baller as shot',
#  'dae le concacaf',
#  'huwoman please educate self',
#  'yeah youre right vanessa used logic whatsoever',
#  'aside joke fucking love man felt strong empathy towards moment',
#  'live gated community germany',
#  'damn',
#  'player entitled everything free',
#  'yeah fun',
#  'must 1010',
#  'there api request limit',
#  'sticking fork light socket quickest way turn light house',
#  'im pretty sure would punch baby real dill pickle',
#  'hey',
#  'nice guy prototype',
#  'youll never pas drug test',
#  'know im padawan one day shitpost',
#  'thanks letting terrorist know',
#  'parenting done right',
#  'encore pire que le vaccins',
#  'im sure free speech crusader echo chamber gamergate come oppose',
#  'yeah get lag parried caestus attack animation finished dumb true',
#  'whole world rigged',
#  'thats simple truth',
#  'im hearing radio',
#  'rip blt guy',
#  'hungrybox isnt fast exciting pop he salty hate',
#  'youre creative',
#  'translation would removing roadhog game improvement current meta',
#  'quitting day job',
#  'remember people good deed unless take photo evidence post reddit',
#  'please',
#  'g',
#  'downloading got free human right',
#  'actually somewhere 80',
#  '14615',
#  'good looking people attractive way physical',
#  'nobody noticed nobody care',
#  'wait thought kenyan genetically superior everyone else would need dope',
#  'someone 9 10 time episode scared shit',
#  'think majority people dipper',
#  'cap vulgar le reddit comedy genius',
#  'yo yo called gillie sute beeoch',
#  'til shouldnt let zac efron repair pc',
#  'way absolutely terrible consider reanimating tr main every single miserable day never win alert',
#  'bet dick pumping blood head',
#  'yeah didnt take picture track ignore backround',
#  'know stoning andor lashing teenage girl raped tennessee demand witness part fun stoning absolutely done muslim law absolutely accurate muslim law prescribes',
#  'seems like hand screaming dont shoot',
#  'win republican primary california though general electorate might hate party electorate apparently dont',
#  'people often squeeze fiddle nose extend hand handshake',
#  'hm let go change',
#  'banned cuz he black tripleblack kappa let riot like ferguson cuz seems help community',
#  'year linux trust',
#  'capitalist pig',
#  'bernie bernie bernie',
#  'actual question people really find sexy',
#  'thats exactly said',
#  'buy c4 high powered rifle',
#  'really',
#  'armor magic pen work exactly way',
#  'id like add ping pong ball',
#  'come conclusion may cooling issue',
#  '',
#  'black people annoying precious little snowflake stopped',
#  'yeah woman alleged action scream deserved murdered',
#  'didnt discriminatie work like everyone else regardless medical condition',
#  'trust news fox know totally unbiased',
#  'today day',
#  'thank god republican relentless defense 2nd amendment least u gun still puncher chance',
#  'wow sure showed',
#  'think mostly funimation stay away yeah monopoly account everything licensed usa',
#  'didnt saying people',
#  'wow everything place park car even walk door house oh wait cant shit place way',
#  'l u l u l',
#  'yeah definitely go butane lighter alumnus glue gun electric heating element handle flamables',
#  'equal useing punishment many parent control kida dress making het go school naked kissed boy make sense obviously need learn slut',
#  'convincing evidence well',
#  'whats wrong cameralady',
#  'claim tactical doesnt flashlight laser dildo attached getting sloppy word gentleman',
#  'yep 10 mana spell destroys board youre fighting board sound great',
#  'well suppose thats true people thought',
#  'jesus christ font ate soul',
#  'dont condone torture think pastor tortured',
#  'idk president able accomplish much still find time pray five time day',
#  'good riddance',
#  'yeah williston north dakota real hippie',
#  'yeah definitely dont live oligarchy',
#  'im smart person',
#  'know anything anything peace doesnt make money',
#  'london must better',
#  'well shouldnt matter american nsa doesnt spy american ya know',
#  'snitch get stitch doe',
#  'cant use software didnt pay dime',
#  'id go killing ugly people dont need world',
#  'plume mold orewwwww',
#  'he sensitive',
#  'could forgive demon worshipping psycho turning mistake',
#  'intel core i76700k corsair h115i corsair vengeance 16gb samsung 850 rvo 500gb wd 2tb hdd waiting evga 1080 ftw acx 30 nzxt h440',
#  'prank bro',
#  'yeah remember one time trump led parade',
#  'maybe stonecutter',
#  'wow really scared shit',
#  'aye buddy ere think youll find wee neary predicament current time u',
#  'well let move bloody sun',
#  'yeah definitely need individual person mean production order produce need',
#  'tool prodigy',
#  'id say thats pretty good considering ps3 much expensive came later 360',
#  'oh manage facebook page',
#  'reload',
#  'story got episode iii everyone know episode ii best',
#  'baconreader',
#  'arent still using 2000',
#  'written law cant bad right',
#  'xb1',
#  'imbaosb',
#  'would people lie anonymous poll',
#  'course would never abuse',
#  'go get',
#  'maybe lucky one',
#  'yeah grizzly adam beard',
#  'think combo three shot trailer',
#  'hey couldve say lead plate pocket',
#  'rip sirnukesalot',
#  'likely joking idiot',
#  'dont make claim person mentally ill unless qualified individual personal stake thisseriously reason doctor tend diagnose treat familyfriends case unethical cause legal issue depending there scrip written extremely detrimental people looking help either given medical advice unqualified people oh sure garlic mixed apple cider vinegar cure cancerdepression right resource takenused people dont need family friend convinced person schizophreniabpdmdd interwebz said',
#  'think bertov may slightly embellished well know english',
#  'wonder would happened people approve gotten ass voted',
#  'would didnt boycott',
#  'careful youre reasonable thoughtful cant much',
#  'stop chem trail giving aid',
#  'nope',
#  'forced would good position greece stay eu debt cut least block bunch stuff others would like',
#  'yup christie 100 innocent knew nothing closure',
#  'yea executed fed dog',
#  'miss tobias',
#  'go click edit flair tool bar right side',
#  'believe',
#  'bandwagon ive suffered frozen crap let go',
#  'h e l e h e l e',
#  'derpshrug idea talkign',
#  'need wall',
#  'agree wheeltimetwister effect sweet storm deck question',
#  'robin marth megaman',
#  'jackboot liberal elitist gaming regulator shouldnt telling u cannot buy child',
#  'hell',
#  'nope',
#  'thanks civil right act there racism america',
#  'put hole belt',
#  'kid',
#  'nah high like 73 day',
#  'rule third putting head 13 way plus fill frame plus heroic angle shoot low make subject appear larger life equal sorry room boot',
#  'please tag post spoiler',
#  'literally asking reddit',
#  'meh master infantry badge cool whatever im still holding expert action badge',
#  'rock poop',
#  'til black ops 3 fov upper limit rocket league',
#  'lol someone give rough translation cell phone saying prompted go yandere',
#  'maybe use cs',
#  'knew making industry legal would create job hmmm sure surprised',
#  'unuh pink shit nasty',
#  'already taken',
#  'really hard find someone offer make one iconic game history',
#  'got paid 500 write comment',
#  'thought one',
#  'individual meant individual personal small capital investment belong private sector',
#  'im saying theyre fighting uphill battle respect concerned image child care',
#  'werent something',
#  'guy cho totally whiny drama whore',
#  'youre using money play youre exploiting game',
#  'incest wincest',
#  'atheist dont believe anything especially moon landing',
#  'dejate de hinchar mandale un mensaje los moderadores del sub quejandote',
#  'there post discussion thread reason',
#  'inject',
#  'sorry forgot',
#  'look username ahhhh',
#  'thank goodness isnt',
#  'ideally want sweep mavs hope spursclippers series go 7 game get undeserving winner series bad officiating',
#  'life best extroverted phase',
#  'thinking could sort as deformity',
#  'logistically',
#  'hey know met sound kind crazy love',
#  'clearly wanted willing put behavior night',
#  'ladder scary safer',
#  'f',
#  'dont understand',
#  'gee world love macho man',
#  'bitcoins',
#  'id bet kanda sayaka going frozen stuff',
#  'legally assume',
#  'sexist',
#  'forgot',
#  'riot never go back decision sell skin made one time offer',
#  'bu bu bu bot',
#  'paid fuck awful performance',
#  'actually good point essentially endorsing everything whine',
#  'miss anabolic window whole workout waste',
#  'whispering build community',
#  'fix bsod get driver window first amd',
#  'wand even trigger',
#  'got spore print',
#  'boy 3tier system sure breed competition',
#  'thought venus',
#  'best company world',
#  'rather airsoft gun shop airport',
#  'badum ti',
#  '',
#  'probably bro trying get dice patch lame glitch',
#  'john key cause everything wrong life instead trying fix easier blame',
#  'bank account',
#  'damn nice map',
#  'kimkanye',
#  'get ball magically attracted pin',
#  'yes miner spend ten thousand pocket keep currency kindness deep heart',
#  'itt 2007',
#  'give nobel peace prize',
#  'isnt nice know small control rest u',
#  'shed 3 tear',
#  'make even sense',
#  'unreal tournament prealpha pretty well show health ammo crosshair almost halfway bottom screen',
#  'age doesnt change make child either',
#  'guy work who like total mma expert told must true',
#  'shutter',
#  'looked good two striker br would option get u going',
#  'try kiss push away',
#  'damn thing',
#  'daft',
#  'pretty sure wont change thing like',
#  'play wtf',
#  'look much poured homeland security surely waste',
#  'patriot friend',
#  'delete',
#  'simple male boss realized woman work 88cents every dollar man make started hiring woman save money',
#  'yeah lol israel fault palestineother surrounding nation done nothing deserve hate expanding boarder',
#  'safe',
#  'exactly',
#  'cool',
#  'grammer nazi ftw',
#  'yes screw rounded put camp dont bother normal people anymore',
#  'nope people crotchety looking older guy japanese wifegfmistresslove slave',
#  'look like pulled pork going say food didnt look terrible aside picture quality',
#  'single intoxicated parent great child safety',
#  'else suppose harem skyrim without mod',
#  'damn phone autocorrect',
#  'fuck would someone install window 98 iphone 6',
#  'im probably going use trainerroad winter first time need work good stand tablet shed',
#  'thanks',
#  'wonder ultron dropped piece land',
#  'phturgeon',
#  '40 pound ago',
#  'cause hotline bling mean one thing social revolution',
#  'trick question isnt op',
#  'tru kvlt',
#  'crack within hour',
#  'boy girl word love',
#  '1v1 sf mid always play defensively',
#  'apparently unless live alaska hawaii',
#  'public school teacher porn',
#  'brown difference right',
#  'see reason extreme vetting mass surveillance',
#  'op dindu nuffin',
#  'eh reek hypocrisy besides tax plan doesnt actually close anyway moot point',
#  'would ironic isnt gaijin japanese word',
#  'find leak website employ people know dump leak',
#  'mean home home series',
#  'shhhhh dont tell anyone im back recon',
#  'gustavsson 185 pretty good',
#  'future sure bright',
#  'stop second guessing next vanilla ice',
#  'yomamma',
#  'luck take whole budget',
#  'totally subjective accounting method lower market rent figured pricevalue building landlord purchased',
#  'pffff probably clarinet',
#  '',
#  'player team something',
#  'yes escort really sister',
#  'thats know youve made',
#  'tofutti taste almost identical regular cream cheese mild le weird richness come dairy',
#  'someone wasnt interested shit crush would totally love',
#  'orwellian',
#  'look like playing roller minus skating skill stickhandling shot',
#  'never go camping',
#  'much pessimism disappointment number people fascinated xenophobia',
#  'would honestly tapefloss penis',
#  'im glad point gay rape funny',
#  'rpolitics',
#  'finger crossed edgy brah',
#  'mean nothing people use fact prove anything',
#  'dont understand business',
#  'seen police disposal',
#  'didnt see anything fleet advert looked like zealot wasnt sure join',
#  'thread',
#  'allow people like get help possibly keep forcibly assaulting black people suspicion marijuana',
#  '11 report',
#  'indian miller beltran',
#  'agree set 100 front 7 gregory 20 would incredibly tempting value considering good could',
#  'want chance emergency crash plane crowded area possible get away',
#  'try elemental shaman',
#  'always lock',
#  'thats kiki kumings shes mfc havent seen',
#  'guess famous celebrity chef tv secretly woman',
#  'username check',
#  'yeah youre right',
#  '3 minute video containing 1 minute skareboarding',
#  'finally sufficient policy possible room misinterpretation',
#  'bottled water work fine one night',
#  'get respawn reduction 3x hp ward',
#  'thought gonna jumping inhale',
#  'think youre sole reason there culture victory civ v',
#  'eu east',
#  'dood fr turn corner well',
#  'woah',
#  'im sure fun wil bringing random people street show',
#  'probably would bunch beeping white noise',
#  'rip chinx still hurt',
#  'people princess though',
#  'course else reddit',
#  'yeah scarlett never beat korean',
#  'scar tissue mean',
#  'probably like dont suffer fool well',
#  'male 38 love loved see',
#  'edgy',
#  'dont understand people dont get secular kurd violent islamist turk',
#  'get pick nice guy sarcastic nice guy',
#  'thats america',
#  'u higher population actually mean uk higher rate homicide',
#  'turn back',
#  'cultural appropriation trigger hard',
#  'best part pay dollar premium shitty quality barely 93 octane anyways',
#  'psh played since capsulemon pls',
#  'better one benchmark make automatically better',
#  'father learn turmoil come multimillionaire eve',
#  'reinhardts king excuse mean come probably referred king',
#  'see top comment thread',
#  'kill child',
#  'bronco',
#  'dota obviously need source 2',
#  'yes christian running around setting people fire cutting head drawing picture jesus',
#  'poor arent allowed anything sawdust bread month old milk',
#  'youre going participate double dutch rudder circle jerk please leave',
#  'gee really must fun party',
#  'get scallop',
#  'rthorgasm good pretty dead place stuff like',
#  'hope there scene tony stark stephen strange someone say something like shit sherlock look something',
#  'current champion',
#  'tell esl bullshit planning',
#  'technical poster racist roadhog he australian he maori new zealand livedworked australia enforcer australian native junkrat',
#  'true love kiss believe',
#  'get wonderland',
#  'like username',
#  'yea itll royal family pay price oppressed citizen',
#  'huh interesting thanks info',
#  'duck tape space grey',
#  'yeah im sure totally fault bus late',
#  'there match thread know',
#  'girl dont use internet',
#  'volkswagen',
#  'hey girl im going need set phaser onto stunning thing thats getting shield frequency',
#  'well course german pretty much nazi inciuding trump',
#  'oh yeah google provide suggestion universally every single person querying see enemy get recommendation',
#  'clearly violates new reddit policy content harasses individual thus silencing',
#  'everyone know commute work need tricked road bike mudguard clipin pedal full lycra',
#  'itt insecure american taking shot china article nothing',
#  'spooky',
#  'seeing team paused prior event likely chose pause',
#  'like others able tell best interest',
#  'bench link clg mancloud',
#  'give loony better access gun great idea',
#  'true christian would ever commit violence',
#  'democracy',
#  'spoiler',
#  '',
#  'well ive gotten one best around medal crucible yeah maybe dont know im talking',
#  'dat dude got bright future',
#  'world go back sanction world bend idiotic u politicans u sanction would make pointless',
#  'glorious',
#  'casa bonito right',
#  'university gun free zone',
#  'cant allow little thing like civil liberty stop u hunting agent godless communist radical islamic terrorist conspiracy matter hide',
#  'thank wealth could imagine',
#  'well',
#  'id break wand',
#  'whoa let get carried away',
#  'get free',
#  'wouldnt harden back',
#  'go hope kubo kojima fuck wsj',
#  'work yelp website arent mobiledesktop instead layout break point based screen resolution phone dont report 1024 point width display',
#  'played like 56 hour put week didnt grab played couldnt put',
#  'keep repeating co know would normally',
#  'mean much lower right',
#  'he clearly acting undercover yatsu point',
#  'title post need opinion proceeds ignore argue every opinion isnt love lol',
#  'turn 980ti titan x',
#  'vast majority police force military civilian use semiautos',
#  'tja een hoop mensen kiezen voor kinderen terwijl ze genetische afwijkingen hebben waar ligt de grens',
#  'he 74 year old police cant take chance',
#  'thinking im gonna shave head grow full beard',
#  'international banking conspiracy want say',
#  'call pennsyltucky reason haha',
#  'obviously kirby',
#  'hit head look imprint plate',
#  'wasnt black priest coverage oppressing black people taking attention away plight',
#  'thanks reddit user',
#  'yea pretty sure icefrog taking shit whole idea raindrop came doneready coded time finished',
#  'damn suck fit shit 25',
#  'oh yeah like people screaming wmd iraq saying president born kenya',
#  '64mb drive hold like dozen high quality mp3s',
#  'ap sharpening end pencil brilliant',
#  'knew eating gluten free important reason idea',
#  'still overpaid tough',
#  'consider couldnt convince someone stop believing god could convince stop believing god want treat people like shit',
#  'get 4some',
#  'mean dont already',
#  'a3 digit reserved valve appid likely hoax',
#  'course would thats justice system work',
#  'officer requires college degree',
#  'yeah chain draped front wheel sprocket absolutely worthless',
#  'hizo nada porque era un buen pibe',
#  'might well stop support taking ignite youre',
#  'go edit flair show picture choose one whatever 19ds duo',
#  'doctor bring legitimate point state cannot solve ensure people finish prescription medication',
#  'ah yes snow crash much le pseudo science',
#  'shit comment shitting shit comment shitting another shit comment shitting shit title',
#  'hmm well quick game restart fixed hope isnt anything permanant',
#  'also ps4 big sexy cock going',
#  'look twitter spyleader used thing',
#  'cps case incoming',
#  'cant wait yoshi yoshi',
#  'rich blame ndp 40 year uninterrupted conservative rule',
#  'noticed performance gain matter icon hanging around screen',
#  '',
#  'another brave 0 day troll',
#  'spend money camera isnt made potato',
#  'well least doesnt brag',
#  'birth control',
#  'would right time ra something thrifting doesntvolume',
#  'alcohol tax tax stupid',
#  'anyone know install minecraft',
#  'learned anything dexter thats exactly stage crime scene',
#  'get femanazi',
#  'forgot',
#  'dunno fool would',
#  'yeah somebody p bose headphone shit',
#  'community college people cant get real college go',
#  'fucking people find motivation shit',
#  'need listen guy he obviously professional stoner',
#  'bad west supported rebel otherwise would never discoveredcould gone',
#  'maybe played seattle',
#  'yea could stabilize wouldnt unless downside',
#  'yes let call cop call day',
#  'pretty sure stand dreamcast',
#  'disappointment realized thumbnail something remove unsightly body hair something eat',
#  'get fuck outta man',
#  'yeah offical ranking accurate interpretation team strengh',
#  'fair enough',
#  'forgot',
#  'cant believe railhawks team',
#  'counted enough time eventually wouldve voted christine gregoire',
#  ...]

# %%
df = pd.DataFrame({"comments": cleaned_corpus, 'labels':data.label})
df.head()
# Out:
#                                             comments  labels
# 0  well let honest dont actually seem much modera...       0
# 1         well didnt need evidence believe communism       1
# 2                                official promo 360p       0
# 3                                   grotto koth best       1
# 4                                    neals back baby       1

# %% [markdown]
# ## Split data into train and test sets

# %%
from sklearn.model_selection import train_test_split

trainx, testx, trainy, testy = train_test_split(df.drop(columns=['labels']), df.labels, test_size=0.2, random_state=32)

# %% [markdown]
# ## Building model with count vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

## Vectorize the words
vectorizer = CountVectorizer().fit(trainx.comments)

## Create vocabulary
vocab = vectorizer.get_feature_names()

## Vectorize train & test
train_dtm = vectorizer.transform(trainx.comments)
test_dtm = vectorizer.transform(testx.comments)
# Out:
# /Users/jervissaldanha/miniforge3/envs/nlpenv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
train_dtm
# Out:
# <12000x14225 sparse matrix of type '<class 'numpy.int64'>'
# 	with 66883 stored elements in Compressed Sparse Row format>

# %%
trainy.values
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
from sklearn.naive_bayes import MultinomialNB

naive_bayes_model = MultinomialNB().fit(train_dtm, trainy)
test_y_pred = naive_bayes_model.predict(test_dtm)

# %%
from sklearn.metrics import accuracy_score, f1_score
print('Accuracy score: ', accuracy_score(testy, test_y_pred))
# Out:
# Accuracy score:  0.6086666666666667

# %% [markdown]
# ## Build model with TF IDF vectorizer

# %%
## Vectorize the words
vectorizer = TfidfVectorizer(min_df=10).fit(trainx.comments)

## Create vocabulary
vocab = vectorizer.get_feature_names()

## Vectorize train & test
train_dtm = vectorizer.transform(trainx.comments)
test_dtm = vectorizer.transform(testx.comments)
# Out:
# /Users/jervissaldanha/miniforge3/envs/nlpenv/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Build Multinomial Naive Bayes Model

# %%
naive_bayes_model = MultinomialNB().fit(train_dtm, trainy)
test_y_pred = naive_bayes_model.predict(test_dtm)

# %%
print('Accuracy score: ', accuracy_score(testy, test_y_pred))
# Out:
# Accuracy score:  0.5986666666666667

# %% [markdown]
# ## Build Logistic regression model

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression().fit(train_dtm, trainy)
test_y_pred = lr_model.predict(test_dtm)
print('Accuracy score: ', accuracy_score(testy, test_y_pred))
# Out:
# Accuracy score:  0.6106666666666667

# %% [markdown]
# ## Build Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier().fit(train_dtm, trainy)
test_y_pred = dtc.predict(test_dtm)
print('Accuracy score: ', accuracy_score(testy, test_y_pred))
# Out:
# Accuracy score:  0.585

# %% [markdown]
# ## Conclusion
#
# We cleaned the text by removing the stop words, applied lemmatization and removed punctuations.
# Also, we used count vectorizer and TF-IDF vectorizer for creating the DTM - Document term matrix which was then used to train the base models.
#
# Accuracy score of Logistic regression model (0.61) is higher compared to MultinomialNB and Decision tree classifier.
